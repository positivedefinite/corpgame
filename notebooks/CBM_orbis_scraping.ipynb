# %%
# load the raw dataset of companies

import pandas as pd
import numpy as np
import pickle
import pyautogui as pg

dir_data = '~/kernel/thesis/data/cbm/'
name_csv = 'cbm_transaction.csv'
df_cbm = pd.read_csv(dir_data + name_csv)

def cols2unique(df, columns):
    '''
    Gets values from columns, puts them together and returns an array of unique values
    '''
    columns_locs = []
    for column in columns:
        columns_locs.append(pd.Series(df[column]))
    locs = pd.concat(columns_locs)
    unique_array = locs.unique()
    return unique_array

companies = cols2unique(df_cbm, columns=['ac_name','mc_name','ac_name_of_group'])
ac_groups = cols2unique(df_cbm, columns=['ac_name_of_group'])

df_cbm.head()
# Out:
#    Transaction_id Transaction_date                                   ac_name  \
# 0               1       2013-04-26                Immobilaire Effetti S.R.L.
# 1               1       2013-04-26                Immobilaire Effetti S.R.L.
# 2               1       2013-04-26                Immobilaire Effetti S.R.L.
# 3               1       2013-04-26                Immobilaire Effetti S.R.L.
# 4               2       2017-10-24  ABN AMRO Commercial Finance Holding B.V.
#
#   ac_location ac_registration_number  \
# 0     Belgium            12326610156
# 1       Italy            12326610156
# 2     Belgium            12326610156
# 3       Italy            12326610156
# 4     Belgium               24263820
#
#                            ac_name_of_group                          mc_name  \
# 0                Immobilaire Effetti S.R.L.                    Luforden B.V.
# 1                Immobilaire Effetti S.R.L.                    Luforden B.V.
# 2                Immobilaire Effetti S.R.L.                    Luforden B.V.
# 3                Immobilaire Effetti S.R.L.                    Luforden B.V.
# 4  ABN AMRO Commercial Finance Holding B.V.  ABN AMRO Commercial Finance Plc
#
#    mc_location mc_registration_number
# 0      Finland            12326610156
# 1      Finland            12326610156
# 2  Netherlands            12326610156
# 3  Netherlands            12326610156
# 4       Sweden               24263820

# %%
# (OPTIONAL) normalization of strings (decode accents etc)

def normalize_strings_in_list(some_list, accept_artifacts = False):
    companies = some_list
    decoded_companies = []
    for company in companies:
        trigger = False
        decoded = unidecode.unidecode(company)
        #normal = unicodedata.normalize('NFKD', company).encode('ASCII', 'ignore')
        decoded = decoded.split(' ')
        for word in decoded:
            if 'NULL' in word:
                decoded.remove(word)
                trigger=True
        decoded = ' '.join(decoded)
        # turns out ORBIS search doesn't work if its anything else
        if trigger==False or accept_artifacts==True:
            decoded_companies.append(decoded)
    return some_list

companies = normalize_strings_in_list(companies, accept_artifacts = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2783daa10b98> in <module>
#      19     return some_list
#      20
# ---> 21 companies = normalize_strings_in_list(companies, accept_artifacts = False)
#
# <ipython-input-7-2783daa10b98> in normalize_strings_in_list(some_list, accept_artifacts)
#       6     for company in companies:
#       7         trigger = False
# ----> 8         decoded = unidecode.unidecode(company)
#       9         #normal = unicodedata.normalize('NFKD', company).encode('ASCII', 'ignore')
#      10         decoded = decoded.split(' ')
#
# NameError: name 'unidecode' is not defined

# %%
# create dictionary of names

import unidecode, unicodedata, pprint, time

dir_path = '/home/op/kernel/thesis/data/orbis/'

dict_num2comp= {str(hash(name))[-10:-1]:name for name in companies}
dict_comp2num= {name:str(hash(name))[-10:-1] for name in companies}
pickle.dump(dict_num2comp, open(dir_path+'dict_num2comp.pickle','wb+'))
pickle.dump(dict_comp2num, open(dir_path+'dict_comp2num.pickle','wb+'))
#pprint.pprint(dict_num2comp)

# %%
# make df of companies

d = {index:{'company':dict_num2comp[index],'country':'','role':'','role_flag':'','transactions':''} for index in dict_num2comp}
df_companies = pd.DataFrame.from_dict(d, orient='index')
df_companies.head()

role_dict = {'ac_name':'AC','mc_name':'MC','ac_name_of_group':'GUO'}

for index in df_cbm.index:
    transaction_id = df_cbm.at[index, 'Transaction_id']
    for column in ['ac_name','mc_name','ac_name_of_group']:
        field = df_cbm.at[index, column]
        role = role_dict[column]
        if df_companies.at[dict_comp2num[field],'role'] not in [role,'']:
            df_companies.at[dict_comp2num[field],'role_flag']=df_companies.at[dict_comp2num[field],'role_flag']+df_companies.at[dict_comp2num[field],'role']
        df_companies.at[dict_comp2num[field],'role']=role
        df_companies.at[dict_comp2num[field], 'transactions'] = df_companies.at[dict_comp2num[field], 'transactions'] + str(transaction_id)+','
        
        df_companies.at[dict_comp2num[df_cbm.at[index, 'ac_name']], 'country'] = df_cbm.at[index, 'ac_location']
        df_companies.at[dict_comp2num[df_cbm.at[index, 'mc_name']], 'country'] = df_cbm.at[index, 'ac_location']
df_companies.head()
# Out:
#                                                 company      country role  \
# 000488369                                  ING Groep NV               GUO
# 000491118                              FormeNULLLimited        Italy   MC
# 000657761                        Rock Fixtures S.à.r.l.      Germany   MC
# 000730245  lronbridge Il Luxembourg Holdings 2 S.à.r.l.   Luxembourg  GUO
# 001048023                          Total (BTC) S.à r.l.  Netherlands   MC
#
#           role_flag  transactions
# 000488369                    809,
# 000491118                    685,
# 000657761                   2421,
# 000730245        AC    1589,1589,
# 001048023            98,98,98,98,

# %%
df_companies[df_companies['role_flag']!='']
# Out:
#                                                      company         country  \
# 000730245       lronbridge Il Luxembourg Holdings 2 S.à.r.l.      Luxembourg
# 003906900                               CMOG Treuhand I GmbH      Luxembourg
# 003974897                                        Maluja B.V.     Netherlands
# 004971480                                      JetVerse B.V.     Netherlands
# 005267917                           Deciding Trading Limited          Cyprus
# 008112422                            Xior Student Housing NV         Belgium
# 008714777                                           DOT S.A.      Luxembourg
# 008849725                                  Cheper Invest, as  Czech Republic
# 009103809                                        Slobel SPRL         Belgium
# 010217884                                 MOL West Oman B.V.     Netherlands
# 010385542                                Treveria D S.à r.l.      Luxembourg
# 010918420                  The True Ice SA (In Liquidazione)     Switzerland
# 011330157  Matrix GmbH (Matrix German Portfolio No. 1 Ver...         Germany
# 011681600  AVR Ausbildungsinstitut fur Verhaltens-therapi...         Germany
# 012197548                          KuppingerCole Analysts AG         Germany
# 012215840                                     Aulularia B.V.     Netherlands
# 013642960                           CologneTechPark Two GmbH         Germany
# 017773872                              Muldershof XVIII B.V.     Netherlands
# 018836180                                      Kolja Limited  United Kingdom
# 019887526                                   CB Holding S.R.L           Italy
# 019921847                       DO-INT CASA AGRÍCOLA, S.L.U.           Spain
# 020663850                              Crea Building Company         Belgium
# 020857567                    CRH RomaNULLHoldings UK Limited  United Kingdom
# 021010264                                      M.V.S.F. S.A.      Luxembourg
# 021588874                                   Brinker MHC B.V.     Netherlands
# 021655149               Paniken-Diagnostics GmbH (dissolved)         Austria
# 022100692                         World Snowboard Federation  Czech Republic
# 022802639                                  TomTom Sales B.V.     Netherlands
# 022878440                                       Quellyn B.V.     Netherlands
# 023075478                            Immobiliare Jacal S.r.l           Italy
# ...                                                      ...             ...
# 972532080                      International Properties S.A.      Luxembourg
# 973882331                        Boortmalt International S.A      Luxembourg
# 974110762                                   Delivery Hero AG         Germany
# 974982956                                    Bodycote S.A.S.          France
# 977299619    British American Tobacco Holdings (Russia) B.V.          Sweden
# 977840785                           Chungmugong Il (II) B.V.     Netherlands
# 978054854                                        NILS S.p.A.           Italy
# 978271084                                     BATHSHEBA S.A.      Luxembourg
# 978456184  RW Sollinger Hütte GmbH (Mageba GmbH) (dissolved)         Austria
# 978754264                                     OVG Cloud GmbH         Germany
# 979229323               Die Green Return Holding S. á. r. l.      Luxembourg
# 979991864                                    HONDA EUROPE NV     Netherlands
# 982456468                 ROBERT BOSCH HOLDING MALTA LIMITED           Malta
# 982904818                              Studio Archi S.á r.l.          France
# 983686823                                    Demaniel S.r.l.           Italy
# 985246630                          Merial Participations SAS          France
# 985695893                                  Jubilee Asia B.V.     Netherlands
# 987890870                  Belfry Lux Participation S.à r.l.      Luxembourg
# 989408238                                 Unibail-Rodamco SE          France
# 989598858                                         Redstar SA     Switzerland
# 989966372                   Konami Digital Entertainment B.V     Netherlands
# 991780535                               Cap Decision S.à r.l      Luxembourg
# 992225034                                      Inmobilia ApS         Denmark
# 994330807                              Nordea Bank AB (publ)         Finland
# 995212212                                    Kesa Hotel B.V.     Netherlands
# 995498445                               Harvest Holding B.V.     Netherlands
# 995597022                         Deutsche Saatveredelung AG         Germany
# 997469331                              Portman Insurance Plc  United Kingdom
# 997826643                   Edmond de Rothschild (France) SA          France
# 998661552                           Yamaha Motor Europe N.V.     Netherlands
#
#           role                                   role_flag  \
# 000730245  GUO                                          AC
# 003906900   MC                                       ACGUO
# 003974897  GUO                                          AC
# 004971480  GUO                                          AC
# 005267917  GUO                                          AC
# 008112422  GUO                                     ACGUOAC
# 008714777  GUO                                          AC
# 008849725  GUO                                          AC
# 009103809  GUO                                          AC
# 010217884  GUO                                          AC
# 010385542  GUO  ACGUOACGUOACGUOACGUOACGUOACGUOACGUOACGUOAC
# 010918420  GUO                                          AC
# 011330157  GUO                                          AC
# 011681600  GUO                                          AC
# 012197548  GUO                                          AC
# 012215840  GUO                                          AC
# 013642960  GUO                                          AC
# 017773872  GUO                                          AC
# 018836180  GUO                                          AC
# 019887526  GUO                                          AC
# 019921847  GUO                                          AC
# 020663850  GUO                                          AC
# 020857567  GUO                                          AC
# 021010264  GUO                                        ACMC
# 021588874  GUO                                          AC
# 021655149  GUO                                          AC
# 022100692  GUO                                        ACMC
# 022802639  GUO                                          AC
# 022878440  GUO                                          AC
# 023075478  GUO                                          AC
# ...        ...                                         ...
# 972532080  GUO                                          AC
# 973882331  GUO                                          AC
# 974110762  GUO                                          AC
# 974982956  GUO                                          AC
# 977299619  GUO                           ACGUOACGUOACGUOAC
# 977840785  GUO                                          AC
# 978054854  GUO                                          AC
# 978271084  GUO                                          AC
# 978456184  GUO                                          AC
# 978754264  GUO                                          AC
# 979229323  GUO                                          AC
# 979991864  GUO                                          AC
# 982456468  GUO                                          AC
# 982904818  GUO                                          AC
# 983686823  GUO                                          AC
# 985246630  GUO                                          AC
# 985695893  GUO                                          AC
# 987890870  GUO                                          AC
# 989408238  GUO                                          AC
# 989598858  GUO                                          AC
# 989966372  GUO                           ACGUOACGUOACGUOAC
# 991780535  GUO                                          AC
# 992225034  GUO                                          AC
# 994330807  GUO                      ACGUOACGUOACGUOACGUOMC
# 995212212  GUO                                          AC
# 995498445  GUO                                          AC
# 995597022  GUO                                          AC
# 997469331  GUO                                          AC
# 997826643  GUO                                          AC
# 998661552   AC                                       ACGUO
#
#                                                 transactions
# 000730245                                         1589,1589,
# 003906900                                    1903,1903,1911,
# 003974897                                         2328,2328,
# 004971480                                           201,201,
# 005267917                                         2114,2114,
# 008112422  1826,1827,1828,1830,1831,1832,1836,1837,1838,1...
# 008714777                                         2550,2550,
# 008849725                                         2145,2145,
# 009103809                                           845,845,
# 010217884                                           144,144,
# 010385542  1930,2270,2270,2271,2271,2272,2272,2273,2273,2...
# 010918420                                         1243,1243,
# 011330157                                         1487,1487,
# 011681600                                         1453,1453,
# 012197548                                         2066,2066,
# 012215840                                         2590,2590,
# 013642960                                         2687,2687,
# 017773872                                         2395,2395,
# 018836180                                         1912,1912,
# 019887526                                           395,395,
# 019921847                                         2536,2536,
# 020663850                                           210,210,
# 020857567                                           780,780,
# 021010264                                    2604,2604,2604,
# 021588874                                         2665,2665,
# 021655149                                           448,448,
# 022100692                                    2729,2729,2729,
# 022802639                                         1775,1775,
# 022878440                                         2338,2338,
# 023075478                                         2119,2119,
# ...                                                      ...
# 972532080                                           700,700,
# 973882331                                         2586,2586,
# 974110762                                         1979,1979,
# 974982956                                         1292,1292,
# 977299619                           46,46,46,46,46,46,46,46,
# 977840785                                         2654,2654,
# 978054854                                           626,626,
# 978271084                                         2582,2582,
# 978456184                                         1572,1572,
# 978754264                                         2697,2697,
# 979229323                                           502,502,
# 979991864                                           705,705,
# 982456468                                         2461,2461,
# 982904818                                         2432,2432,
# 983686823                                         1132,1132,
# 985246630                                         2742,2742,
# 985695893                                         2650,2650,
# 987890870                                         2076,2076,
# 989408238                                           800,800,
# 989598858                                           671,671,
# 989966372                           80,80,80,80,80,80,80,80,
# 991780535                                           799,799,
# 992225034                                         1769,1769,
# 994330807  1264,1264,1265,1265,1266,1266,1359,1374,1374,1...
# 995212212                                         2337,2337,
# 995498445                                         2330,2330,
# 995597022                                       433,434,434,
# 997469331                                           764,764,
# 997826643                                           620,620,
# 998661552           1579,1579,1819,1833,1847,1879,1880,1882,
#
# [1276 rows x 5 columns]

# %%
# SCRAPER get search results
from PIL import Image
import pytesseract, os
images = []
dir_path = '/home/op/kernel/thesis/data/orbis/ocr/'


def get_company(company):
    pg.moveTo(293,237)
    pg.click()
    pg.hotkey('ctrl','a')
    pg.press('delete')
    pg.typewrite(company, interval=0.1)
    #print(company)
    time.sleep(6)
    file_name = dict_comp2num[str(company)]
    im = pg.screenshot(dir_path+file_name+'.png',region=(77, 256, 710, 552))
    text= pytesseract.image_to_string(Image.open(dir_path+file_name+'.png'))
    #images.append(text)
    with open(dir_path+file_name+'.png.txt','w') as f:
        f.write(text)
    pass


import os
file_names = []
for file in os.listdir(dir_path):
    # append all files names to a list
    if file[0]!='.' and file[-3:]=='png': #to handle issue with hidden files and non-pdf files
        file_names.append(file[:-4])
file_names

counter = 0

for number in dict_num2comp.keys():
    if number not in file_names:
        get_company(dict_num2comp[number])
        print(counter, number, dict_num2comp[number])
    counter+=1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-25d7ca65aa6c> in <module>
#      25 import os
#      26 file_names = []
# ---> 27 for file in os.listdir(dir_path):
#      28     # append all files names to a list
#      29     if file[0]!='.' and file[-3:]=='png': #to handle issue with hidden files and non-pdf files
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/op/kernel/thesis/data/orbis/ocr/'

# %%
# data processing of first scraper 
import pandas as df

for file in os.listdir(dir_path):
    # append all files names to a list
    if file[0]!='.' and file[-3:]=='png': #to handle issue with hidden files and non-pdf files
        file_names.append(file[:-4])
file_names

corpnet_id = {'0':list(dict_num2comp.keys())}
text = {name:None for name in dict_num2comp.keys()}
for file in file_names:
    with open(dir_path+file+'.png.txt') as f:
        text[file]=f.read()

df_companies = pd.concat([
                        pd.DataFrame.from_dict(dict_num2comp, orient='index',columns=['name']),
                        pd.DataFrame.from_dict(text, orient='index',columns=['text']), 
                        #pd.DataFrame.from_dict(dict(G.out_degree()), orient='index',columns=['text']),
                         ], axis=1, join='outer')
df_companies.to_csv('/home/op/kernel/thesis/data/orbis/all_texts.csv')
text = df_companies.loc['021676583','text']
df_companies.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-228-4573289acfde> in <module>
#      11 text = {name:None for name in dict_num2comp.keys()}
#      12 for file in file_names:
# ---> 13     with open(dir_path+file+'.png.txt') as f:
#      14         text[file]=f.read()
#      15
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/op/kernel/thesis/data/orbis/185925173.png.txt'

# %%
# find which names have NULL
null_names = []
for name in df_companies['name']:
    if 'NULL' in name:
        null_names.append(name)
        print(name)
        
len(null_names)
# Out:
# GoNULLez Byass, S.A.
# RouNULLout Tours B.V.
# SaNULLossa Capital Investments B.V.
# SeNULL Corporation S.L.
# General Mills Luxembourg FiNULLce S.a r.l
# Harsco International FiNULLce S.a r.l.
# RheiNULLd Versicherungs AG
# Oriola FiNULLd Oy
# Belfius FiNULLcing Company
# Volkswagen FiNULLce Luxemburg S.A.
# Societe Generale Capital Market FiNULLce eNULLrege SGCMF
# Atlantic CoNULLner Line AB
# GAZPROM GermaNULLGmbH
# Yellow MouNULLn S.a r.l.
# FiNULLcial Performance Holdings B.V.
# SaNULL Investment Holdings UK Limited
# BiNULLle International Corporation B.V.
# Telecom Italia FiNULLce
# Chiquita BaNULLa Company B.V. (now Chiquita Europe B.V.)
# Robert Bosch FiNULLce Nederland B.V.
# Robert Bosch IC FiNULLcing Nederland B.V.
# Tiberton Yard FiNULLce Limited
# ZNULLylekarz Holdings sp. z o.o
# JPF FiNULLce Trust Ltd.
# TarNULLk Rederi AB
# TarNULLk Holding AB
# Generali FiNULLce B.V.
# 0-Park FiNULLcial Services
# NV
# TP Vision DeNULLk A/S
# GuNULL W. Publishing B.V.
# TP Vision FiNULLd Oy
# Lundin FiNULLce (Cyprus) Limited
# VatteNULLl S.A.S.
# VatteNULLl Sahkontuotanto Pamilo Aktiebolag
# ENULLNetbricks SAS
# DeNULLBeheer B.V.
# JM DaNULLk A/S
# Arvika MoNULLje AS
# TeNULLt Forsakringsaktiebolag
# Man FiNULLcial Services S.A.S.
# VatteNULLl Nederland B.V.
# HoNULLLogistics Center Sweden AB
# Trygg-HaNULLForsakringsaktiebolag (publ)
# SaNULLder Consumer Bank AB
# Woonfront -AntoNULLVeerstraat Delft B.V.
# CoNULLSystems Limited
# ReNULL Homes APS
# Ritchie Bros. HuNULLy Szolgaltato Korlatolt Felelossegu Tarsasag
# ABN AMRO Commercial FiNULLce
# GmbH
# INULLo Holding Limited
# Commerz FiNULLz GmbH
# MH Power Systems Engineering VieNULLGmbH
# TiNULL Filmhandels GmbH
# StaNULLd & Poor's Credit Market Services Europe Limited
# Spiess-UraNULLGmbH
# ABN AMRO FiNULLcing S.a r.l.
# EiNULLfszentrum Rothenburg/Tbr. Besitz GmbH
# HaNULLArla Milch eG
# BMG NoveNULLS.r.l.
# AFH fiNULLcni a.s.
# ALLSHARE FiNULLce Central Europe, as
# Trebol FiNULLce Ireland Limited
# SPX Flow Technology FiNULLd OY
# Physio-Control FiNULLd Sales Oy
# Physio-Control DeNULLk Sales ApS
# TA MouNULLnstream II Sweden AB
# SeveNULL FiNULLs AB
# SEB Kapitalforvaltning FiNULLd Ab
# 288

# %%
import pandas_profiling
df_companies.profile_report()

# %%
PART 2

# %%
#df = df_companies[df_companies['country'].isin(['Netherlands','Estonia','Finland','Germany','Luxembourg','Sweden','Poland','Italy'])]
df = df_companies.copy()
#df = df[df['role'].isin(['GUO','AC'])]
df['score']=df['role_flag'].str.len()
df_companies_filtered= df.sort_values(by='score', ascending=False)
df_companies_filtered = df_companies_filtered.drop(columns = ['role_flag','transactions'])
df_companies_filtered.to_csv('/home/op/kernel/thesis/data/orbis/companies.csv')
df_companies_filtered
# Out:
#                                                      company         country  \
# 737432500  Octopus Liegenschaftsverwaltungsgesellschaft m...         Austria
# 281236465                          Aleris Aluminum Vogt GmbH         Denmark
# 125210818                                        EPF Neli OÜ         Estonia
# 010385542                                Treveria D S.à r.l.      Luxembourg
# 413788916                         Venetsalo Holdings Limited          Cyprus
# 560460488                            PoloNULLProperty S.à rl      Luxembourg
# 773049444                        RP Complex Holding S.à.r.l.      Luxembourg
# 994330807                              Nordea Bank AB (publ)         Finland
# 510880349                                         Virvi B.V.     Netherlands
# 883274265                        Viega Holding GmbH & Co. KG         Germany
# 626742142                        CACEIS Bank Luxembourg S.A.          France
# 575807887                             Alfa Wassermann S.p.A.  United Kingdom
# 688718644  GUO     17
# 739663995  GUO     17
# 596108248  GUO     17
# 373425364  GUO     17
# 438407512  GUO     17
# 355985899  GUO     17
# 094339980  GUO     17
# 292454484  GUO     17
# 812883351  GUO     17
# 316799558  GUO     17
# 088012207  GUO     17
# 768863988  GUO     17
# 989966372  GUO     17
# ...        ...    ...
# 371171240   MC      0
# 373921288   MC      0
# 371137489   MC      0
# 371110554   MC      0
# 370866150   AC      0
# 370106252   MC      0
# 370073070   AC      0
# 370005580   MC      0
# 369898243   MC      0
# 373838794   MC      0
# 374538325   MC      0
# 378716697   AC      0
# 376344121   MC      0
# 378430555   MC      0
# 378375807   MC      0
# 377539717   MC      0
# 376886297   MC      0
# 376839969   MC      0
# 376820615   AC      0
# 376406919   MC      0
# 375988807  GUO      0
# 374602355   MC      0
# 375940603   MC      0
# 375192976   MC      0
# 375096392  GUO      0
# 374931389   AC      0
# 374738511   MC      0
# 374730545  GUO      0
# 374724301   MC      0
# 999720471   MC      0
#
# [5890 rows x 4 columns]

# %%
for file in os.listdir(dir_path):
    # append all files names to a list
    if file[0]!='.' and file[-3:]=='png': #to handle issue with hidden files and non-pdf files
        file_names.append(file[:-4])
file_names
# Out:
# ['904439362', '014731448', '904439362', '014731448']

# %%
df_companies_filtered.shape
# Out:
# (3213, 4)

# %%
#191029 Getting ownership info
import os
dir_path = '/home/op/kernel/thesis/data/orbis/ocr_ownership/'
dir_buttons = '/home/op/kernel/thesis/data/orbis/buttons/'

ui = { 'search_button' : (27,263),
         'search_bar' : (199,250),
         'first_search_result' : (175,325),
         'new_search_confirm': (674, 506)}

file_names = []

for file in os.listdir(dir_path):
    # append all files names to a list
    if file[0]!='.' and file[-3:]=='png': #to handle issue with hidden files and non-pdf files
        file_names.append(file[:-4])
print(len(file_names), df_companies.shape)
with open(dir_path+'tainted.txt','r') as f:
    for line in f.readlines():
        file_names.append(line[:-1])
print(len(file_names), df_companies.shape)

for index in df_companies_filtered.index:
    #print(index)
    if index not in file_names:
        company = df_companies.at[index, 'company']
        pg.moveTo(ui['search_button'])
        pg.click()
        time.sleep(4)
        pg.moveTo(ui['search_bar'])
        pg.click()
        pg.hotkey('ctrl','a')
        pg.press('delete')
        pg.typewrite(company, interval=0.1)
        pg.moveTo(ui['first_search_result'])
        time.sleep(5)
        pg.click()
        pg.moveTo(ui['new_search_confirm'])
        time.sleep(3)
        pg.click()
        time.sleep(5)
        loc = pg.locateOnScreen(dir_buttons+'ownership_more.png')
        if loc!=None:
            location = (loc[0]+20,loc[1]+45,280,60)
            im = pg.screenshot(dir_path+index+'.png',region=location)
            ownership = pytesseract.image_to_string(Image.open(dir_path+index+'.png'))
            with open(dir_path+index+'.png.txt','w') as f:
                f.write(company)
                f.write('\r\n')
                f.write(ownership)
            im = pg.screenshot(dir_path+index+'.png',region=(300,130,950,920))
            print(company)
            print(ownership)
        else:
            with open(dir_path+'tainted.txt','a+') as f:
                f.write(index)
                f.write('\r\n')
# Out:
# 3778 (5890, 5)
# 5890 (5890, 5)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-343e62ec9005> in <module>
#      44             location = (loc[0]+20,loc[1]+45,280,60)
#      45             im = pg.screenshot(dir_path+index+'.png',region=location)
# ---> 46             ownership = pytesseract.image_to_string(Image.open(dir_path+index+'.png'))
#      47             with open(dir_path+index+'.png.txt','w') as f:
#      48                 f.write(company)
#
# NameError: name 'pytesseract' is not defined

# %%
from PIL import Image
import pytesseract
images = []
dir_path = '/home/op/kernel/thesis/data/orbis/ocr/'


def get_company(company):
    pg.moveTo(293,237)
    pg.click()
    pg.hotkey('ctrl','a')
    pg.press('delete')
    pg.typewrite(company, interval=0.1)
    #print(company)
    time.sleep(6)
    file_name = dict_comp2num[str(company)]
    im = pg.screenshot(dir_path+file_name+'.png',region=(77, 256, 710, 552))
    text= pytesseract.image_to_string(Image.open(dir_path+file_name+'.png'))
    #images.append(text)
    with open(dir_path+file_name+'.png.txt','w') as f:
        f.write(text)
    pass
    
print(images)

# %%
get_company()
# Out:
# name BLACKROCK. INC
# location NEW YORK, NY, United States of Amé
# guo Publicly quoted
# This company is the Global Ultimate Owner of the corporate group
# activity Finance company (credit card
# full_address 55 EAST S2ND STREET,PAR
# NEW YORK, NY, NY 10055-C
# United States of America
# incorporation_date
# ownership More :
#
# ‘Ownership

# %%
# when executed records the position of the mouse for how_many_seconds
import pyautogui as pg
import time

how_many_seconds = 5

def record():
    t = time.time()
    r = []
    while((time.time()-t)< how_many_seconds):
        time.sleep(2)
        r.append(pg.position())
        print(r[-1])
    return r
#pg.dragTo(50,50)
pg.click()
r = record()
# Out:
# Point(x=1843, y=317)
# Point(x=674, y=506)
# Point(x=1800, y=501)

# %%
regions = {'name': (402, 254, 163, 20),
           'location': (401, 283, 219, 17),
           'guo':(623, 325, 474, 38),
           'activity': (778, 455, 351, 19),
           'full_address': (329, 449, 165, 65),
           'incorporation_date': (780, 477, 246, 16),
           'ownership': (330, 681, 268, 85)
          }


from PIL import Image
import pytesseract
images = []
dir_path = '/home/op/kernel/thesis/data/orbis/ocr_tests/'


def get_company(company=None):
    for region_name in regions:
        im = pg.screenshot(dir_path+region_name+'.png',region=regions[region_name])
        text= pytesseract.image_to_string(Image.open(dir_path+region_name+'.png'))
        print(text)
        #images.append(text)
        with open(dir_path+region_name+'.png.txt','w') as f:
            f.write(text)
    pass
get_company()
#print(images)
# Out:
# name TOOLS-LENA. S.R.O.
# location HRADEC KRALOVE, Czech Republic:
# guo Private
# The Global Ultimate Owner of this controlled subsidiary is MR JIRI VACLAVICEK
# activity Corporate, Property Services
# full_address POUCHOVSKA 533/524
# 50003 HRADEC KRALOVE
# Czech Republic
# incorporation_date Date of incorporation:
# ownership Ownership
#
# 1 shareholder
# 0 subsidiary
# 2 companies in the corporate group

# %%
im = pg.screenshot(dir_path+'ownership.png',region=(316, 768, 95, 40))

# %%
loc = pg.locateOnScreen(dir_buttons+'ownership_more.png')
location = (loc[0]+20,loc[1]+45,280,60)
im = pg.screenshot(dir_path+'ownership_found.png',region=location)
text= pytesseract.image_to_string(Image.open(dir_path+'ownership_found.png'))
print(text)
im
#pg.moveTo(location[0],location[1])
# Out:
# 2 shareholders
# 3 subsidiaries
# 29 companies in the corporate group
# <PIL.Image.Image image mode=RGB size=280x60 at 0x7F3096A2E4A8>

# %%
def get_region():
    print('Go!')
    time.sleep(2)
    p1 = pg.position()
    print(p1)
    time.sleep(2)
    p2 = pg.position()
    print(p2)
    region =(p1[0],p1[1],p2[0]-p1[0],p2[1]-p1[1])
    print('Box :', region)
    print('Center :', (int(region[0]+region[2]/2), int(region[1]+region[3]/2)))
    print('Size: ', (region[2], region[3]))
    return region

region = get_region()
# Out:
# Go!
# Point(x=316, y=768)
# Point(x=411, y=808)
# Box : (316, 768, 95, 40)
# Center : (363, 788)
# Size:  (95, 40)

# %%
dir_buttons = '/home/op/kernel/thesis/data/orbis/buttons/'
im = pg.screenshot(dir_buttons+'select_all_search.png',region=(371, 731, 154, 32))
im
# Out:
# <PIL.Image.Image image mode=RGB size=154x32 at 0x7F30C00D6668>

# %%
import cv2, pytesseract, imutils
cv2.imread('/home/op/kernel/thesis/data/orbis/snap.png', 0)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
# OCR that sees itself

import re
for i in range(0,10):
    t=time.time()
    im = pg.screenshot(dir_path+'test_all_screen.png')
    text= pytesseract.image_to_string(Image.open(dir_path+'test_all_screen.png'))
    match = re.findall('Oskar', text)
    see_self = re.findall('I see myself', text)
    see_this = 'I see myself '+str(len(see_self))+' times!'
    end = time.time()-t
    print(end, len(match), see_this)
# Out:
# 3.9915666580200195 3 I see myself 12 times!
# 3.8526225090026855 3 I see myself 2 times!
# 3.899962902069092 3 I see myself 3 times!
# 3.8587939739227295 3 I see myself 4 times!
# 3.964635133743286 3 I see myself 5 times!
# 3.962472915649414 3 I see myself 6 times!
# 4.078366041183472 3 I see myself 7 times!
# 4.1080732345581055 3 I see myself 8 times!
# 4.087390184402466 3 I see myself 9 times!
# 4.188660383224487 3 I see myself 10 times!

# %%
print(text)
# Out:
# eee Ee Sec eee Cod
#
#
#
#
#
#
#
# # Orbis|Companyinform X | Data & Analytics inM& Gi Mail- Oskar Person-O lees sland CBM_orbis_anal) X [RGMEODIEEGEREeas Robin Cowan X © pyautoguiforau' x + Advanced Python X | M Automationwit
# <)> ¢@ o\a live.com “Ow snoom Ae c@ | © localhost 8 * snoom Ae Ws
# ESworkspace £5 Thesis Slashdot Papers °< GeeksforGeeks {4 AutomationCourse # GoodNews —Cloud Wars @Medium [MJ Top Links| HackerNews [JIT AAI ESworkspace i Thesis 4 Slashdot Papers °< GeeksforGeeks 1 AutomationCourse # GoodNews — Cloud Wars @Medium [J TopLinks|HackerNews [IT SAI >»
#
#
#
#
#
#
#
# eae ... VAMWELH-_AWE k WEN S jupyter CBM_orbis_scraping Last checkpoint 16 minutes ago (ansaved changes) By Logout
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# © Mark all as read File Edit View Insert Cell_~«Kernel_~— Widgets ‘Help Tw [Pythons @
# Ey fark all as reat
# B+) BB ey WRU mC coue |=
# > Favorites © egFocused Other Filters cv2. imread(' /home/op/kernel/thesis/data/orbis/snap.png’, 0)
# out[47]: array([[255, 255, 255, ..., 255, 255, 255],
# Y RoE (Other: New conversations GitHub; Twitter; Kraken; Microsoft PowerApps and Flow; Lyft; Revolut ee aes, aes, ve aes, aes, seel
# > tiie 3 @& pera atamas ©) Re:Polaris guests Hi Oskar, Due to the ming number of applications, we had to make a decisi 2 [255, 255, 255, ..., 255, 255, 255],
# [255, 255, 255, ..., 255, 255, 255],
# eee y | © Bolmer, BRI (lifelines) Sf] P= Re: Catching up Hi Oskar, Just wanted to send you a reminder regarding the comments on the article. 4 [255, 255, 255, ..., 255, 255, 255]], dtype-uint8)
# @ Drafts 58 oe jolanta.person@wp.pl Pd: AW: AW: Niederlande Sprawdz gdzie utkneta Dnia 29 paZdziernika 2019 08:02 Drexler <aon.9136 114 PES
# ‘t=time.time()
# Sent Items Yesterday im = pg.screenshot(dir_path+'test_all_screen.png')
# ‘text= pytesseract. image to_string(Image.open(dir_path+'test_all_screen.png'))
# WH Deleted items 238 | Tableau Software Watch Tableau In Action Analytics fo 12. Watch Now In case you haven't started your trial, yo Mon 164 match = re.findall(‘Oskar', text)
# see self = re.findall('I see myself’, text)
# this = "I Lf teste (L Lf))+" times! *
# Archive eo Suzanne Van Der Velden Reminder PA Pizza Session | Q-learning in practice Dear Oskar Person, It is still possible to join our PA Mon 13 aE eG aa StaiLen(scoRse Ui) aaaeinc
# print(end, len(match), see this)
# CDE This month
# 6.577463626861572 13 I see myself 1 times!
# 6.044512987136841 14 I see myself 1 times!
# Conversation Hist @ niantaperson@wppt Polacy w Holandii_https://wiadomosci wp.pl/poruszajace-uroczystosci ndii-dziekujemy-wam- sun 22 6.209987169549701 13 I see myself 2 tines!
# 6.2500083446502686 13 I see myself 3 times!
# T Notes | Tableau Software Your Trial Is Waiting Data, Set, Go! Download Now Copyright © 2019 Tableau All Rights Res sun 164 6.242554426193237 13 I see myself 4 times!
# 6. 1456193923950195 13 I see myself 5 times!
# 40.40 6.134871482849121 13 I see myself 6 times!
# Social Medi  @ - Am Freistein 42 40822 Mettmann | ca joc fo i104
# social Media Laura Thiel @ RE: Rental Agreement DRAFT - signed Am Freistein 42 40822 Mettmann | doc for Frit0 6 te0364524841300 La I cee mest? 7 tine!
# Travel Services 473 | =
# £:-3/& print (text)
# New folder Baa eats def get region()
# @ weve trie © 0 RE:Rental Agreement DRAFT - signed Sent from Mall for Windows 10 From: Oskar Person Sent. Fri 104 ss print (*Go!")
# Secrets 2 ental agreeme... || [Zl Rental Agreeme ia time.steep(2)
# Pl = pg.position()
# Odyssey Co-write Self-Sovereign Identity’s Next Chapter Dutch Blockchain Coalition, Ministry of the Interior, an Frit04 see
# @ oi euts - corr RE: Consense Data Exchange BV. Hi Oskar, Are you available for as ? With kind regards, Ol Fri 104 rv
# eo Diana Mitroi (via Calendly) Confirmed: 60 Minute Meeting with Diana Mitroi on Wednesday, November 6, 2019 Hi Oskar Person, Fri 104 + Connect Outlook Marcus 1 day 2¢
# Ee Oskar Person 1:01 PM here are some resources from the Master course that I Linked
# © cr007 Kraak Re: 7th Nov 2019 Odyssey Polaris = logistics AAARGGHH, \V' 0 talk. My 2 day Focus SPrint wa Frit04 nice article on scraping 7A
# a ff A | EazzyPark | Parkeren Eindhoven Airport _Herfstvoordeel # Parkeer met €5 korting Voor al onze vaste klanten: reserveer een parkeerplek met Fri 104
#
# Xe ac i di 13:12
#
# Orca) Seeger cee eto
# or
#
# eee le ca Ras ec Be
# ao a Ula slack-com . ,noo tm Ae
#
# ESworkspace $5 Thesis QM Slashdot Papers °< GeeksforGeeks {4 AutomationCourse i GoodNews —Cloud Wars @ Medium [MJ Top Links| Hacker News []IT JAI Ej}Community [Bankruptcy E{RabbitHole [|FromGoogle Chrome Rave >>
#
# PEE creul Elia Bogdan Covrig
# kar Pers 2 | @ active | Bogdan Covrig
# J t ma
# a
# I set up pyautogui + OCR witl Thread
# CPU History Marcus
# wes Bogdan Covrig 5:39 Pm
#
# a @ ps RK 63 Oskar Person oct 27th at 9:13 PM
# Channels G 0 2019-10-28 at 17.30 BX | started with Tableau. Would you have any worksheets that
#
# Ne x Su 2
# Niteare mee 5 ; ; = you could share with me:
#
# gaze CPU2 2,8% PU3 100,0% CPU4 58,8% 9 rel
#
# Pet) TM crus 564% = [BB cPu7 11,9% CPUS 13,0% Marcus 1 day as
#
# random Memory and Swap History Nice! Do you want to lear how to use Tableau or what is
#
# . your goal with this? | can recommend these tutorials for the
#
# TE
# ast
#
# ect
# rkshop is it working for you?
#
#
#
#
#
#
#
#
#
#
#
#
#
# basics, which comes with a dummy dataset and worksheets:
#
# >pDomM*#e@a
#
#
#
# 20 70 a” It is currently not on sale, but should be again in a few days or
# Memory }) Swap so for a couple of Euros. | cannot share the project
#
# §3 Oskar Person 5:40PM 10,9 GiB (70,6%) of 15,5 GiB 26,0 MIB (1,3%) of 2,0 GiB worksheets with you, though.
#
# Se ENe rl interesting, not
#
# Network History & Udemy
#
# Oskar Person 5:37 °
# Pra erycry Untitled » f\
#
# Orda
#
# ‘one
#
# # when executed rec Master data visualization in tableau desktop. Covers
#
# eds Toe import pyautogui as - . <2 SW: +0 tableau certification syllabus and more. Tableau
# Neat import time Tutorials (13 kB)
# Receiving 365 bytes/s Sending 434 bytes/s
#
# TotalReceived 1,1GiB TotalSent 150,0 MiB
# lay
# rao Kats
#
# def get_region()
# print(‘Go!")
# time. sleep(2)
# p1 = pg.position()
#
# wy
# )
#
# IVE Raty
# See
#
# rv @
#
# Caden Cee Marcus 1 day 2¢
#
# SCE sy §3 Oskar Person 1:01PM here are some resources from the Master course that I linked
# nice article on scraping 7A
#
#
#
#
#
# ESC-2016-grand-final-full-results.txt
# 29 kB Plain Text

# %%
loc=pg.locateOnScreen(im)

# %%
def mcw(x,y):
    '''
    Move, click and wait!
    '''
    pg.moveTo(x,y)
    pg.click()
    time.sleep(3)

images = []

for company in companies[1:2]:
    pg.moveTo(293,237)
    pg.click()
    pg.typewrite(company)
    #pg.press('enter')
    time.sleep(3)
    #mcw(293,407)
    #mcw(590,768)
    #mcw(1642,748) #PDF button
    images.append(pg.screenshot(region=(81,215, 236, 275)))

# %% [markdown]
# companies[-100:-10]
