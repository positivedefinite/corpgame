# Romania           52064   53720   53824
# Slovenia           7172    7386    7492
# Slovakia          14849   15566   16358
# Finland           19730   20129   20716
# Sweden            38583   39407   40127
# United Kingdom   210215  217245  220460
# Iceland            1654    1820    1943
# Norway            25917   26117   26523
# Switzerland       49857   49887   50265
# North Macedonia       :       :       :
# Serbia                :       :   16804
# Turkey           197417       :       :

# %%
player_labels = ['Netherlands', 'Germany', 'Luxembourg', 'Italy', 'Sweden', 'Austria',
       'United Kingdom', 'Finland', 'France', 'Spain', 'Belgium', 'Denmark',
       'Norway', 'Czech Republic', 'Cyprus', 'Ireland', 'Estonia', 'Poland']
for label in player_labels:
    df.loc[label]

# %%
np.random.rand(1)/3
# Out:
# array([0.2604274])

# %%
starting_state = np.random.randint(0, 1, (len(player_labels),2))
for i, label in enumerate(player_labels):
    companies = df.loc[label, '2009']
    a = np.random.randint(0, companies)
    b = companies - a
    print(companies, a, b)
    starting_state[i, :] = [a,b]
starting_state
# Out:
# 57629 30181 27448
# 252863 24531 228332
# 3996 2446 1550
# 173986 69519 104467
# 35502 27582 7920
# 36936 16933 20003
# 186660 8725 177935
# 18381 15081 3300
# 180405 126531 53874
# 143894 82881 61013
# 30781 20370 10411
# 18565 16221 2344
# 23021 21819 1202
# 44930 20737 24193
# 3815 211 3604
# 18420 5561 12859
# 6947 3582 3365
# 92014 44213 47801
# array([[ 30181,  27448],
#        [ 24531, 228332],
#        [  2446,   1550],
#        [ 69519, 104467],
#        [ 27582,   7920],
#        [ 16933,  20003],
#        [  8725, 177935],
#        [ 15081,   3300],
#        [126531,  53874],
#        [ 82881,  61013],
#        [ 20370,  10411],
#        [ 16221,   2344],
#        [ 21819,   1202],
#        [ 20737,  24193],
#        [   211,   3604],
#        [  5561,  12859],
#        [  3582,   3365],
#        [ 44213,  47801]])

# %%
import numpy as np
companies = 500
a = np.random.randint(0, companies)
b = companies - print(a, b)
# Out:
# 442 58

# %%
starting_state = np.random.randint(0, 2000, (18,2))
starting_state[5, :] = [0,0]
starting_state
# Out:
# array([[1772,   43],
#        [ 445,   72],
#        [ 435, 1899],
#        [ 978,  628],
#        [1590,  880],
#        [   0,    0],
#        [1774, 1195],
#        [1510,   82],
#        [ 149, 1169],
#        [1455,  618],
#        [ 819,  705],
#        [1515, 1797],
#        [ 751, 1561],
#        [1155,  760],
#        [1057, 1998],
#        [1238,  675],
#        [ 410,  683],
#        [1338,  863]])

# %%
import networkx as nx
G = nx.erdos_renyi_graph(18,0.1)
nx.draw(G)
print(G.edges)
# Out:
# [(0, 3), (0, 17), (1, 2), (1, 3), (2, 9), (2, 11), (3, 6), (4, 8), (8, 14), (11, 16), (12, 17), (13, 14)]
# C:\Users\Kinga\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
